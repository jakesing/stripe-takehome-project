# %% [markdown]
# # Jake Singer Stripe Takehome Workbook
# ## Table of Contents
#
# 1. [Initial Setup](#Initial-Setup)
# 2. [Data Overview](#Data-Overview)
# 3. [Cleanup and Merging](#Cleanup-and-Merge)
# 4. [Segmentation Analysis](#Segmentation-Analysis)
# 5. [Identifying Successes](#Identifying-Successful-Adopters-of-Subscriptions)
# 6. [Identifying Target Merchants](#Identifying-Target-Merchants)
# 7. [ROI Analysis](#ROI-Analysis)

# %% [markdown]
# ## Initial Setup
# In this step we'll load any necessary packages, import the data, and ensure it worked correctly.

# %%
import pandas as pd
import numpy as np
import datetime

# import merchants data
merchants = pd.read_excel('dstakehome_merchants.xlsx', parse_dates=['first_charge_date'])

# import payments data
payments = pd.read_excel('dstakehome_payments.xlsx', parse_dates=['date'])

# verify the data was imported correctly
print("Merchants table shape:", merchants.shape)
print("Payments table shape:", payments.shape)
# Out:
# Merchants table shape: (23627, 5)
# Payments table shape: (1577887, 6)

# %% [markdown]
# ## Data Overview
# In this step we'll look at an overview of basic information to make sure we understand the structure of our data

# %%
# get basic information
def print_dataframe_info(df, name):
    print(f"\n{name} DataFrame Overview:")
    print(df.info())

# check for mixed type issues
def check_mixed_types(df, df_name):
    print(f"\nChecking mixed types in {df_name}:")
    for column in df.columns:
        # Get unique types in the column
        unique_types = df[column].apply(type).unique()
        
        if len(unique_types) > 1:
            print(f"\nColumn '{column}' has mixed types:")
            for dtype in unique_types:
                count = (df[column].apply(type) == dtype).sum()
                print(f"  {dtype.__name__}: {count}")
        else:
            print(f"Column '{column}' only has one type: {unique_types[0].__name__}")

# get summary stats for merchants for categorical data columns
def summarize_merchants(df):
    print("\nMerchants Table Detailed Summary:")
    
    categorical_cols = ['industry', 'country', 'business_size']
    
    for col in categorical_cols:
        print(f"\nTop 10 {col} categories:")
        counts = df[col].value_counts()
        total = len(df)
        
        if len(counts) > 10:
            top_10 = counts.head(10)
            other = pd.Series({'Other': counts[10:].sum()})
            top_10 = pd.concat([top_10, other])
        else:
            top_10 = counts
        
        summary = pd.DataFrame({
            'Count': top_10,
            '% of Total': (top_10 / total * 100).round(2)
        })
        
        print(summary)

# get summary stats for payments data to understand distribution at a basic level
def summarize_payments(df):
    print("\nPayments Table Detailed Summary:")
    
    volume_cols = ['subscription_volume', 'checkout_volume', 'payment_link_volume', 'total_volume']
    
    for col in volume_cols:
        non_zero = df[df[col] > 0][col]
        zero_count = (df[col] == 0).sum()
        non_zero_count = len(non_zero)
        
        print(f"\n{col}:")
        print(f"Zero values: {zero_count:,} ({zero_count/len(df)*100:.2f}%)")
        print(f"Non-zero values: {non_zero_count:,} ({non_zero_count/len(df)*100:.2f}%)")
        
        if non_zero_count > 0:
            print("Summary statistics for non-zero values:")
            stats = non_zero.describe()
            print(f"Ratio of mean to median: {non_zero.mean()/non_zero.median()}")
            print(stats.apply(lambda x: f"{x:,.2f}" if isinstance(x, (int, float)) else x))

# print the summaries for merchants and payments
print_dataframe_info(merchants, "Merchants")
summarize_merchants(merchants)

print_dataframe_info(payments, "Payments")
summarize_payments(payments)

# run the mixed type function on both dataframes
check_mixed_types(payments, "Payments")
check_mixed_types(merchants, "Merchants")
# Out:
# Merchants DataFrame Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23627 entries, 0 to 23626
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   merchant           23627 non-null  object
#  1   industry           23627 non-null  object
#  2   first_charge_date  23627 non-null  object
#  3   country            23627 non-null  object
#  4   business_size      23627 non-null  object
# dtypes: object(5)
# memory usage: 923.1+ KB
# None
#
# Merchants Table Detailed Summary:
#
# Top 10 industry categories:
#                        Count  % of Total
# Business services       3144       13.31
# Software                2167        9.17
# Merchandise             1988        8.41
# Personal services       1922        8.13
# Others                  1732        7.33
# Digital goods           1379        5.84
# Education               1332        5.64
# Clothing & accessory    1303        5.51
# ...

# %% [markdown]
# There are a few key points to highlight about the data that is beyond what is included in the data description file. This is useful just to develop some intuition around the data:
#
# 1. The payments table includes 1.6M rows of daily merchant payment volume. Most of the rows have a 0 for at least one of the three columns. There are significant long tails in each of these columns. Even after excluding the zero rows for each of the payments volume, the ratio of the mean to the median is large. This is especially true for subscription and total revenue.
# 2. Merchants are relatively evenly distributed by industry, but are more concentrated by country (about 50% of records in the US and GB). Merchants are even more concentrated by size, where over 90% of records are considered 'small'.
# 3. There a few columns that have 'mixed types', as in columns that have more than 1 data type. For merchant and industry, we'll cast all values to string.
# 4. Finally, the first_charge_date column is type 'object', and I want to make sure that is in the data type of datetime so we can more reliably run operations on it.
# 5. This is also a good time to remember that the data is in cents, not dollars, so we'll divide all the volume columns by 100 so the rest of the analysis is a bit easier to read.
#
# To go deeper in understanding the data, I want to merge the data so I can start to segment the payments data by merchant attributes.

# %% [markdown]
# ## Cleanup and Merge

# %% [markdown]
# ### Step 1: Initial Cleanup
# We'll clean up the data using the insights from the previous step

# %%
# convert first_charge_date to datetime (note: coercing values of 0 to NaT, which after trying this I learned exist
merchants['first_charge_date'] = pd.to_datetime(merchants['first_charge_date'], utc=True, errors='coerce')

# cast merchant and industry values to strings
payments['merchant'] = payments['merchant'].astype(str)
merchants['merchant'] = merchants['merchant'].astype(str)
merchants['industry'] = merchants['industry'].astype(str)

# convert volume columns from cents to dollars
volume_columns = ['subscription_volume', 'checkout_volume', 'payment_link_volume', 'total_volume']
payments[volume_columns] = payments[volume_columns].div(100)

# %% [markdown]
# ### Step 2: Merge Tables
# Note refactored initial code into functions since I'll be running a 2nd merge later (more info below).

# %%
# function to perform the merge
def perform_merge(payments_df, merchants_df):
    merged_df = pd.merge(payments_df, merchants_df, on='merchant', how='left')
    return merged_df

# function to check the basic info of the dataframes
def check_dataframes_info(payments_df, merchants_df, merged_df):
    print("Shape of payments:", payments_df.shape)
    print("Shape of merchants:", merchants_df.shape)
    print("Shape of merged dataframe:", merged_df.shape)
    print("Extra Rows as result of merge:", len(merged_df) - len(payments_df))

# function to check for null values in all columns
def check_null_values(df, column):
    print(f"\nNull values in '{column}' column:")
    print(df[column].isnull().sum())

# function to compare unique values before and after merge
def compare_unique_values(payments_df, merged_df, column):
    print(f"\nUnique {column} in payments:", payments_df[column].nunique())
    print(f"Unique {column} in merged dataframe:", merged_df[column].nunique())

# function to check for duplicate rows
def check_duplicates(df):
    print("\nNumber of duplicate rows:", df.duplicated().sum())

# function to sample rows
def sample_rows(df, n=5):
    print(f"\nSample of merged dataframe ({n} rows):")
    print(df.sample(n))

# function to print column names
def check_column_names(df):
    print("\nColumns in merged dataframe:")
    print(df.columns)

# function to run the merge and diagnostics that were defined above
# Function to perform the merge and diagnose the resulting dataframe
def merge_and_diagnose(payments_df, merchants_df):
    # Perform the merge
    merged_df = pd.merge(payments_df, merchants_df, on='merchant', how='left')
    
    # Check the shapes of the dataframes
    check_dataframes_info(payments_df, merchants_df, merged_df)
    
    # Check for null values in key columns
    check_null_values(merged_df, 'business_size')
    
    # Compare unique merchants before and after merge
    compare_unique_values(payments_df, merged_df, 'merchant')
    
    # Check for any duplicate rows
    check_duplicates(merged_df)
    
    # Sample a few rows to manually verify
    sample_rows(merged_df)
    
    # Check for unexpected column names
    check_column_names(merged_df)

    # Return the merged dataframe for further use
    return merged_df


merged_df = merge_and_diagnose(payments,merchants)
# Out:
# Shape of payments: (1577887, 6)
# Shape of merchants: (23627, 5)
# Shape of merged dataframe: (1578937, 10)
# Extra Rows as result of merge: 1050
#
# Null values in 'business_size' column:
# 0
#
# Unique merchant in payments: 23620
# Unique merchant in merged dataframe: 23620
#
# Number of duplicate rows: 0
#
# Sample of merged dataframe (5 rows):
#                              date  merchant  subscription_volume  \
# 74174   2041-05-22 00:00:00+00:00  228f5de6                724.0
# 334714  2041-08-04 00:00:00+00:00  fd6962e4                  0.0
# 155828  2041-06-14 00:00:00+00:00  52461eb0                  0.0
# 1125802 2042-03-02 00:00:00+00:00  83f91bb1                  0.0
# 1268978 2042-04-07 00:00:00+00:00  86ed373e                  0.0
#
#          checkout_volume  payment_link_volume  total_volume  \
# 74174                0.0                  0.0       5256.00
# 334714               0.0                  0.0         29.00
# ...

# %% [markdown]
# From here we can see the merge is mostly successful, but we have 1,050 extra rows created. My guess is this is related to duplicate merchants in one of the tables.

# %%
# check for duplicate merchants in the merchants table
duplicate_merchants = merchants[merchants.duplicated(subset='merchant', keep=False)]
print("Number of duplicate merchant entries:", len(duplicate_merchants))
print("\nSample of duplicate merchants:")
print(duplicate_merchants)

# check how many payments are affected by these duplicates
affected_payments = payments[payments['merchant'].isin(duplicate_merchants['merchant'])]
print("\nNumber of payments affected by duplicate merchants:", len(affected_payments))
# Out:
# Number of duplicate merchant entries: 8
#
# Sample of duplicate merchants:
#       merchant           industry         first_charge_date country  \
# 11282        0         Healthcare 2040-12-08 00:00:00+00:00      US
# 11606        0        Merchandise 2038-11-30 00:00:00+00:00      CA
# 13020        0          Education 2041-07-15 00:00:00+00:00      MX
# 13384        0             Others 2041-07-24 00:00:00+00:00      GB
# 18458        0  Business services 2041-12-16 00:00:00+00:00      US
# 20739        0             Others 2042-03-10 00:00:00+00:00      US
# 21151        0             Others 2042-03-26 00:00:00+00:00      GB
# 22686        0            Leisure 2042-05-22 00:00:00+00:00      SG
#
#       business_size
# 11282         small
# 11606         small
# 13020         small
# 13384         small
# 18458         small
# 20739         small
# 21151         small
# 22686         small
#
# Number of payments affected by duplicate merchants: 150

# %% [markdown]
# This suggests there are 8 duplicated merchants, who all have the id of "0". Let's explore these and big of an issue this is:

# %%
# filter the rows where the 'merchant' is '0'
zero_merchant_payments_original = payments[payments['merchant'] == '0']
zero_merchant_payments_merged = merged_df[merged_df['merchant'] == '0']

# function to convert scientific notation to percentage string
def sci_to_percent(value):
    return f"{value * 100:.4f}%"

# calculate and print percentages
total_volume_pct = sci_to_percent(zero_merchant_payments_original['total_volume'].sum() / payments['total_volume'].sum())
total_rows_pct = sci_to_percent(len(zero_merchant_payments_original) / len(payments))

print(f"Percent of total payment volume connected to '0' merchant: {total_volume_pct}")
print(f"Percent of total rows connected to '0' merchant: {total_rows_pct}")
# Out:
# Percent of total payment volume connected to '0' merchant: 0.0005%
# Percent of total rows connected to '0' merchant: 0.0095%

# %% [markdown]
# Based on this, the volumes are really small, so I think we can just go back to the original tables and just re-do the merge, but this time filtering out merchants with ID = '0':

# %%
# filter out '0' merchants
merchants_filtered = merchants[merchants['merchant'] != '0']
payments_filtered = payments[payments['merchant'] != '0']

# Perform the merge and diagnose for the filtered data
merged_df_filtered = merge_and_diagnose(payments_filtered, merchants_filtered)
# Out:
# Shape of payments: (1577737, 6)
# Shape of merchants: (23619, 5)
# Shape of merged dataframe: (1577737, 10)
# Extra Rows as result of merge: 0
#
# Null values in 'business_size' column:
# 0
#
# Unique merchant in payments: 23619
# Unique merchant in merged dataframe: 23619
#
# Number of duplicate rows: 0
#
# Sample of merged dataframe (5 rows):
#                              date  merchant  subscription_volume  \
# 1535478 2042-06-12 00:00:00+00:00  22a989cc                  0.0
# 438202  2041-09-02 00:00:00+00:00  8d520578                  0.0
# 1296845 2042-04-14 00:00:00+00:00  eda9f28b                  0.0
# 213568  2041-07-01 00:00:00+00:00  704312c0                  0.0
# 948166  2042-01-17 00:00:00+00:00  c9c3f8a0                  0.0
#
#          checkout_volume  payment_link_volume  total_volume  \
# 1535478             0.00                  0.0         58.32
# 438202              0.00                  0.0         34.48
# ...

# %% [markdown]
# OK so we now have a merged dataframe. Before doing more analysis, I want to do a few final quality checks:
# * That transaction dates in payments 'date' column aren't too far outside of the range we are expecting (2041-42)
# * That the 'first_charge_date' reflects what we see in date - like we should not have payments occuring before the first_charge_date for a given merchant.

# %%
# function to define quality checks
def quality_check(df):
    # check 1: Transaction dates range
    print("1. Checking transaction date range:")
    min_date = df['date'].min()
    max_date = df['date'].max()
    print(f"   Minimum date: {min_date}")
    print(f"   Maximum date: {max_date}")
    
    # Check 2: first_charge_date vs date
    print("\n2. Checking first_charge_date consistency:")
    inconsistent = df[df['date'] < df['first_charge_date']]
    inconsistent_count = len(inconsistent)
    total_count = len(df)
    inconsistent_percentage = (inconsistent_count / total_count) * 100

    print(f"   Number of inconsistent records: {inconsistent_count}")
    print(f"   Percentage of inconsistent records: {inconsistent_percentage:.2f}%")

    if inconsistent_count > 0:
        print("\nSample of inconsistent records:")
        print(inconsistent[['merchant', 'date', 'first_charge_date']].head())

    return inconsistent

# run quality checks on final filtered df
inconsistent_records = quality_check(merged_df_filtered)
# Out:
# 1. Checking transaction date range:
#    Minimum date: 2041-05-01 00:00:00+00:00
#    Maximum date: 2042-06-22 00:00:00+00:00
#
# 2. Checking first_charge_date consistency:
#    Number of inconsistent records: 8
#    Percentage of inconsistent records: 0.00%
#
# Sample of inconsistent records:
#         merchant                      date         first_charge_date
# 349510  4e91a7c6 2041-08-08 00:00:00+00:00 2041-09-05 00:00:00+00:00
# 353121  4e91a7c6 2041-08-09 00:00:00+00:00 2041-09-05 00:00:00+00:00
# 356832  4e91a7c6 2041-08-10 00:00:00+00:00 2041-09-05 00:00:00+00:00
# 627961  f3b90aa7 2041-10-24 00:00:00+00:00 2041-12-06 00:00:00+00:00
# 779333  b3b86d1c 2041-12-02 00:00:00+00:00 2041-12-03 00:00:00+00:00

# %% [markdown]
# This makes me feel pretty good - there are 8 "inconsistent" records, but the dates are close enough, and the volume is low enough that I'm happy to ignore these.
#
# ## Segmentation Analysis
# Now that we have our data merged, we can start to segment merchants by their payments activity. We'll segment merchants by size, country, and industry, and for each breakdown, look at the following data:
# - Merchant count
# - average daily volume per merchant(total)
# - average daily volume per merchant (subscription)
# - adoption of subscriptions (% of merchants with at least 1 day of subscription volume)
# - penetration of subscriptions (average % of total volume coming from subscriptions)

# %%
df = merged_df_filtered

# ---- Function to calculate metrics ----
def calculate_metrics(grouped_df, df, group_by_column):
    # ensure all data points appear as numbers 
    pd.options.display.float_format = '{:.2f}'.format

    # calculate daily average volume and subscription volume per merchant
    grouped_df['daily_average_volume_per_merchant'] = grouped_df['total_volume'] / grouped_df['unique_merchants_count'] / grouped_df['unique_days']
    grouped_df['daily_average_subscription_volume_per_merchant'] = grouped_df['subscription_volume'] / grouped_df['unique_merchants_count'] / grouped_df['unique_days']

    # calculate subscription volume as a percent of total volume
    grouped_df['subscription_penetration'] = (grouped_df['subscription_volume'] / grouped_df['total_volume']) * 100
    grouped_df['subscription_penetration'] = grouped_df['subscription_penetration'].fillna(0).map('{:,.2f}%'.format)

    # calculate percent_adoption
    merchants_with_subscription = df[df['subscription_volume'] > 0].groupby(group_by_column)['merchant'].nunique().reset_index(name='merchants_with_subscription')
    total_merchants = df.groupby(group_by_column)['merchant'].nunique().reset_index(name='total_merchants')

    # merge and calculate percent_adoption
    adoption = pd.merge(total_merchants, merchants_with_subscription, on=group_by_column, how='left')
    adoption['percent_adoption'] = (adoption['merchants_with_subscription'] / adoption['total_merchants']) * 100
    adoption['percent_adoption'] = adoption['percent_adoption'].fillna(0).map('{:,.2f}%'.format)

    # final merge
    final_df = pd.merge(grouped_df, adoption[[group_by_column, 'percent_adoption']], on=group_by_column, how='left')

    # drop unwanted columns
    final_df = final_df.drop(columns=['total_volume', 'subscription_volume', 'unique_days'], errors='ignore')

    return final_df

# ---- Table 1: Grouped by business_size ----
grouped_by_size = df.groupby('business_size').agg(
    total_volume=('total_volume', 'sum'),
    subscription_volume=('subscription_volume', 'sum'),
    unique_merchants_count=('merchant', 'nunique'),
    unique_days=('date', 'nunique')
).reset_index()

final_by_size = calculate_metrics(grouped_by_size, df, 'business_size')

# ---- Table 2: Grouped by country ----
grouped_by_country = df.groupby('country').agg(
    total_volume=('total_volume', 'sum'),
    subscription_volume=('subscription_volume', 'sum'),
    unique_merchants_count=('merchant', 'nunique'),
    unique_days=('date', 'nunique')
).reset_index()

final_by_country = calculate_metrics(grouped_by_country, df, 'country')

# ---- Table 3: Grouped by industry ----
grouped_by_industry = df.groupby('industry').agg(
    total_volume=('total_volume', 'sum'),
    subscription_volume=('subscription_volume', 'sum'),
    unique_merchants_count=('merchant', 'nunique'),
    unique_days=('date', 'nunique')
).reset_index()

final_by_industry = calculate_metrics(grouped_by_industry, df, 'industry')

# Sort tables by unique merchants count
final_by_size = final_by_size.sort_values(by='unique_merchants_count', ascending=False)
final_by_country = final_by_country.sort_values(by='unique_merchants_count', ascending=False).head(10)
final_by_industry = final_by_industry.sort_values(by='unique_merchants_count', ascending=False).head(10)

# Print the results
print("Final Table Grouped by Business Size:")
print(final_by_size)

print("\nFinal Table Grouped by Country (Top 10):")
print(final_by_country)

print("\nFinal Table Grouped by Industry (Top 10):")
print(final_by_industry)
# Out:
# Final Table Grouped by Business Size:
#   business_size  unique_merchants_count  daily_average_volume_per_merchant  \
# 2         small                   22845                             209.41
# 1        medium                     622                            4432.87
# 0         large                     152                           39366.62
#
#    daily_average_subscription_volume_per_merchant subscription_penetration  \
# 2                                           32.55                   15.54%
# 1                                         1142.97                   25.78%
# 0                                          177.83                    0.45%
#
#   percent_adoption
# 2           18.62%
# 1           20.74%
# 0           18.42%
#
# Final Table Grouped by Country (Top 10):
#    country  unique_merchants_count  daily_average_volume_per_merchant  \
# 43      US                    8592                             844.00
# ...

# %% [markdown]
# This segmentation is really interesting. A few key findings:
# - Adoption by size is pretty consistent, with all three size buckets adopting subscriptions at a clip between 18 and 21 percent. However, the percent of total_volume that comes from subscription varies heavily by size. Large companies receive only 0.45% of their volume from subscriptions compared to 15% and 25% for small and medium sized companies, respectively.
# - For countries, there are clear divides in both adoption rate and penetration, and likewise for industries.
# - I think it would be useful to visualize this relationship in a series of scatterplots. Adding these below, with size indicating average daily volume, and the rest being self explanatory.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# ---- Helper Function to Convert Percentages from Strings to Floats ----
def convert_percent_columns(df, percent_columns):
    for column in percent_columns:
        # Check if the column has any '%' symbols to remove before converting to float
        if df[column].dtype == 'object':  # Only proceed if the column is an object type (i.e., string)
            df[column] = df[column].str.replace('%', '').astype(float)
        else:
            df[column] = df[column].astype(float)
    return df

# Convert percent columns back to numeric for plotting
final_by_size = convert_percent_columns(final_by_size, ['percent_adoption', 'subscription_penetration'])
final_by_country = convert_percent_columns(final_by_country, ['percent_adoption', 'subscription_penetration'])
final_by_industry = convert_percent_columns(final_by_industry, ['percent_adoption', 'subscription_penetration'])

# ---- Scatterplot Function with Labels and Size by Volume ----
def plot_scatter(df, x_col, y_col, label_col, size_col, title):
    plt.figure(figsize=(10, 8))
    
    # Create the scatter plot, scaling the size of the points by daily volume
    sns.scatterplot(data=df, 
                    x=x_col, 
                    y=y_col, 
                    size=size_col, 
                    sizes=(50, 1000),  # Adjust this range to scale the sizes appropriately
                    legend=False, 
                    alpha=0.7)

    # Add labels for each point
    for i in range(df.shape[0]):
        plt.text(df[x_col].iloc[i], 
                 df[y_col].iloc[i], 
                 df[label_col].iloc[i], 
                 fontsize=9, 
                 ha='right', 
                 va='center', 
                 alpha=0.8)

    plt.title(title)
    plt.xlabel(x_col.replace('_', ' ').title())
    plt.ylabel(y_col.replace('_', ' ').title())
    plt.grid(True)
    plt.show()

# Scatterplot for Business Size with Labels
plot_scatter(final_by_size, 'percent_adoption', 'subscription_penetration', 'business_size', 'daily_average_volume_per_merchant', 'Percent Adoption vs Percent of Sales (Business Size)')

# Scatterplot for Country with Labels
plot_scatter(final_by_country, 'percent_adoption', 'subscription_penetration', 'country', 'daily_average_volume_per_merchant', 'Percent Adoption vs Percent of Sales (Country)')

# Scatterplot for Industry with Labels
plot_scatter(final_by_industry, 'percent_adoption', 'subscription_penetration', 'industry', 'daily_average_volume_per_merchant', 'Percent Adoption vs Percent of Sales (Industry)')

# %% [markdown]
# There are certainly many segments with large customers where subscription adoption and penetration is low. One approach we could take with this analysis is to focus on those pockets.
#
#
# However, given the time constraint, we will stay focused on the original plan.

# %% [markdown]
# ## Identifying Successful Adopters of Subscriptions
#
# In this section we will be identifying successful subscription adopters. These are merchants that meet the following criteria:
#
# - Adopted subscriptions at some point in the dataset timeframe
# - Average daily total volume after adopting subscriptions was 1x or more larger than total volume before adopting subscriptions
# - Average daily total volume was >= $25
# - At least 15 days both before and after subscription adoption

# %%
# Load the data
df = merged_df_filtered
subscription_adopting_merchants = df.groupby('merchant').agg(total_subscription_volume=('subscription_volume', 'sum')) > 0
df_filtered = df[df['merchant'].isin(subscription_adopting_merchants[subscription_adopting_merchants.total_subscription_volume].index)]

# Confirming that the filter worked properly
print(f"Number of unique merchants with subscriptions: {df_filtered['merchant'].nunique()}")
print(f"Number of unique merchants in original dataset: {df['merchant'].nunique()}")

def analyze_merchant(merchant_data):
    # Find first subscription date
    first_sub_date = merchant_data[merchant_data['subscription_volume'] > 0]['date'].min()
    
    # Split data into before and after
    before_data = merchant_data[merchant_data['date'] < first_sub_date]
    after_data = merchant_data[merchant_data['date'] >= first_sub_date]
    
    # Count days before and after
    before_days = (before_data['date'].max() - before_data['date'].min()).days + 1
    after_days = (after_data['date'].max() - after_data['date'].min()).days + 1
    
    # Calculate average daily total volume before and after
    before_avg_daily = before_data['total_volume'].sum() / before_days if before_days > 0 else 0
    after_avg_daily = after_data['total_volume'].sum() / after_days if after_days > 0 else 0
    
    # Calculate growth ratio
    growth_ratio = after_avg_daily / before_avg_daily if before_avg_daily > 0 else np.inf
    
    # Calculate subscription percentage before and after
    before_sub_percent = (before_data['subscription_volume'].sum() / before_data['total_volume'].sum()) * 100 if before_data['total_volume'].sum() > 0 else 0
    after_sub_percent = (after_data['subscription_volume'].sum() / after_data['total_volume'].sum()) * 100 if after_data['total_volume'].sum() > 0 else 0
    
    return pd.Series({
        'before_days': before_days,
        'after_days': after_days,
        'before_avg_daily': before_avg_daily,
        'after_avg_daily': after_avg_daily,
        'growth_ratio': growth_ratio,
        'before_sub_percent': before_sub_percent,
        'after_sub_percent': after_sub_percent
    })

# Apply the analysis to each merchant
results = df_filtered.groupby('merchant').apply(analyze_merchant, include_groups=False).reset_index()

days_threshold = 15
growth_threshold = 0
sales_threshold = 25
results_filtered = results[(results['before_days'] >= days_threshold) & 
                           (results['after_days'] >= days_threshold) & 
                           (results['growth_ratio'] >= 1 + growth_threshold) &
                            (results['before_avg_daily'] >= sales_threshold)
]

growth_ratio_threshold = results_filtered['growth_ratio'].quantile(0.95)
results_filtered = results_filtered[results_filtered['growth_ratio'] <= growth_ratio_threshold]

# Sort by growth ratio
results_sorted = results_filtered.sort_values('growth_ratio', ascending=False)

print("Top 10 merchants by growth ratio (10%+ growth, excluding top 1%):")
print(results_sorted[['merchant', 'growth_ratio', 'before_avg_daily', 'after_avg_daily', 'before_sub_percent', 'after_sub_percent']].head(10))

print("\nSummary statistics (10%+ growth, excluding top 1%):")
print(results_filtered.describe())
print(f"\nTotal merchants analyzed: {len(results_filtered)}")
print(f"Average growth ratio: {results_filtered['growth_ratio'].mean():.2f}")
print(f"Median growth ratio: {results_filtered['growth_ratio'].median():.2f}")
print(f"Average subscription percentage before adoption: {results_filtered['before_sub_percent'].mean():.2f}%")
print(f"Average subscription percentage after adoption: {results_filtered['after_sub_percent'].mean():.2f}%")

# Additional insights
print("\nAdditional Insights:")
print(f"Merchants with over 50% subscription volume after adoption: {(results_filtered['after_sub_percent'] > 50).sum()}")
print(f"Average growth for merchants with >50% subscription volume: {results_filtered[results_filtered['after_sub_percent'] > 50]['growth_ratio'].mean():.2f}")
print(f"Average growth for merchants with <=50% subscription volume: {results_filtered[results_filtered['after_sub_percent'] <= 50]['growth_ratio'].mean():.2f}")

# Distribution of growth ratios
print("\nDistribution of Growth Ratios:")
bins = [1.1, 1.25, 1.5, 2, 3, 5, 10, float('inf')]
labels = ['10-25%', '25-50%', '50-100%', '100-200%', '200-400%', '400-900%', '900%+']
results_filtered['growth_category'] = pd.cut(results_filtered['growth_ratio'], bins=bins, labels=labels, include_lowest=True)
print(results_filtered['growth_category'].value_counts().sort_index())
# Out:
# Number of unique merchants with subscriptions: 4410
# Number of unique merchants in original dataset: 23619
# Top 10 merchants by growth ratio (10%+ growth, excluding top 1%):
#       merchant  growth_ratio  before_avg_daily  after_avg_daily  \
# 1159  4450a540          7.28             29.73           216.43
# 2170  7d9fbab8          7.27             77.35           562.61
# 184   0b541830          6.87             99.97           686.96
# 572   21fee24a          6.72            139.20           935.56
# 2264  82a88fd0          6.69             27.30           182.60
# 3136  b4cf0572          6.08             97.40           592.32
# 3813  ddb7bd7a          5.81            114.64           666.16
# 4181  f2f2ed58          5.27             78.17           411.78
# 2205  7fa36b9a          5.11             76.97           393.34
# 2191  7ec92a56          4.94             42.15           208.13
#
#       before_sub_percent  after_sub_percent
# ...

# %% [markdown]
# We found 167 merchants who met the criteria, out of almost 4,000 who adopted subscriptions overall. This is a smaller population than I'd have liked, and playing around with the filters, it looks like there simply aren't too many folks who both adopted subscriptions and had more than 15 days before and after the adoption. In the interest of time, I'll keep going, but I'd love to have more data to work with here to have more confidence in the conclusions.
#
# Below we will look at these 167 merchants and see what patterns we can pull out. We'll look for signals by country, size, industry, and their use of other products (checkout and payment links).

# %%
# create a list of these successful merchants
successful_merchants = results_filtered['merchant']

# merge characteristics with results
merchant_characteristics = df_filtered[df_filtered['merchant'].isin(successful_merchants)].groupby('merchant').agg({
    'industry': 'first',
    'country': 'first',
    'business_size': 'first',
    'checkout_volume': lambda x: (x > 0).any(),
    'payment_link_volume': lambda x: (x > 0).any()
}).rename(columns={
    'checkout_volume': 'uses_checkout',
    'payment_link_volume': 'uses_payment_link'
})

results_with_characteristics = results_filtered.merge(merchant_characteristics, on='merchant')

# function to calculate percentages and differences between these folks and the overall sample
def compare_distributions(successful_series, overall_series, top_n=10):
    successful_counts = successful_series.value_counts()
    overall_counts = overall_series.value_counts()
    
    comparison = pd.DataFrame({
        'Successful Count': successful_counts,
        '% of Successful': (successful_counts / successful_counts.sum()) * 100,
        '% of Overall': (overall_counts / overall_counts.sum()) * 100
    })
    
    comparison['Difference (pp)'] = comparison['% of Successful'] - comparison['% of Overall']
    
    return comparison.sort_values('Successful Count', ascending=False).head(top_n)

# compare industries
industry_comparison = compare_distributions(results_with_characteristics['industry'], df_filtered['industry'])
print("\nTop 10 Industries Comparison:")
print(industry_comparison.round(2))

# compare countries
country_comparison = compare_distributions(results_with_characteristics['country'], df_filtered['country'])
print("\nTop 10 Countries Comparison:")
print(country_comparison.round(2))

# business size distribution
print("\nBusiness Size Distribution:")
print(results_with_characteristics['business_size'].value_counts(normalize=True).mul(100).round(2))

# product usage analysis
results_with_characteristics['product_usage'] = (
    results_with_characteristics['uses_checkout'].astype(str) + '_' +
    results_with_characteristics['uses_payment_link'].astype(str)
).map({
    'True_True': 'Both',
    'True_False': 'Cnheckout Only',
    'False_True': 'Payment Links Only',
    'False_False': 'Neither'
})

overall_avg_growth = results_with_characteristics['growth_ratio'].mean()

product_usage_analysis = results_with_characteristics.groupby('product_usage').agg({
    'merchant': 'count',
    'growth_ratio': 'mean'
}).rename(columns={'merchant': 'Merchant Count', 'growth_ratio': 'Avg Growth Ratio'})

product_usage_analysis['% of Merchants'] = product_usage_analysis['Merchant Count'] / product_usage_analysis['Merchant Count'].sum() * 100
product_usage_analysis['Comparison vs Overall (pp)'] = (product_usage_analysis['Avg Growth Ratio'] - overall_avg_growth) 

product_usage_analysis = product_usage_analysis.reindex(columns=[
    'Merchant Count', '% of Merchants', 'Avg Growth Ratio', 'Comparison vs Overall (pp)'
])

print("\nProduct Usage Analysis:")
print(product_usage_analysis.round(2))

print(f"\nOverall Average Growth Ratio: {overall_avg_growth:.2f}")
# Out:
# Top 10 Industries Comparison:
#                                         Successful Count  % of Successful  \
# industry
# Business services                                  37.00            22.16
# Personal services                                  25.00            14.97
# Digital goods                                      16.00             9.58
# Software                                           16.00             9.58
# Education                                          14.00             8.38
# Merchandise                                         8.00             4.79
# Religion, politics & other memberships              7.00             4.19
# Others                                              6.00             3.59
# Charity                                             4.00             2.40
# Furnishing                                          4.00             2.40
#
#                                         % of Overall  Difference (pp)
# industry
# ...

# %% [markdown]
# From this analysis, our successful merchants show some interesting characteristics:
# - Merchants in Business Services, Personal services, Education, and Merchandise are overrepresented. This means these industries are disproportionately likely to have successful merchants.
# - 95% of our successful merchants are small. This should cause us some concern: we know that medium and large merchants adopt subscriptions at similar rates, so we might want to investigate why the 'successful' merchants are not showing as many merchants from those segments.
# - The countries that are overrepresented include US, GB, AU, HK, and MX
# - The product usage is not too instructive. The average growth rates for all segments here are relatively close to one another.
# - For our successful merchants, we've observed a 92% increase (1.92x) in total volume after adoption of subscriptions compared to before. While this is of course not enough to conclude causality, we could use this in a marketing message to other similar merchants.

# %% [markdown]
# ## Identifying Target Merchants
# Based on the analysis above, we'll write queries to identify target merchants for our marketing campaign.
#
# In addition to matching the characteristics we identified above

# %%
import pandas as pd
from datetime import timedelta

# Define the target criteria
target_industries = ['Business services', 'Personal services', 'Merchandise', 'Education', 'Software']
target_countries = ['US', 'GB', 'AU', 'HK', 'MX']

days_threshold = 15

# Get the latest date in the dataset and expand the range to the last n days
latest_date = merged_df_filtered['date'].max()
last_n_days = latest_date - timedelta(days=days_threshold -1)  # Expanding the date range

# Filter for the last n days of data
df_last_n_days = merged_df_filtered[merged_df_filtered['date'] >= last_n_days]

# Summarize merchant activity and volume in the last n days
merchant_summary = df_last_n_days.groupby('merchant').agg({
    'date': 'nunique',
    'total_volume': 'sum',
    'industry': 'first',
    'country': 'first',
    'payment_link_volume': lambda x: (x > 0).any()
}).reset_index()

# Calculate the daily average volume in dollars
merchant_summary['average_total_volume_daily'] = (merchant_summary['total_volume'] / days_threshold) / 100  

# Apply updated criteria for target merchants
target_df = merchant_summary[
    (merchant_summary['industry'].isin(target_industries)) &
    (merchant_summary['country'].isin(target_countries)) &
    (merchant_summary['date'] >= 0) &  # Reduced minimum active days
    (merchant_summary['average_total_volume_daily'] >= 10)  # Lowered threshold
]

# Filter out merchants who are already using subscriptions
target_df = target_df[~target_df['merchant'].isin(subscription_adopting_merchants[subscription_adopting_merchants.total_subscription_volume > 0].index)]

# Rename columns for consistency
target_df = target_df.rename(columns={'merchant': 'merchantId', 'payment_link_volume': 'uses_product_links'})

# Keep only the required columns
target_df = target_df[['merchantId', 'country', 'industry', 'average_total_volume_daily', 'uses_product_links', 'date']]

# Display results and summaries
print(target_df.head())
print(f"\nTotal number of target merchants: {len(target_df)}")
print("\nMerchants by country:")
print(target_df['country'].value_counts())
print("\nMerchants by industry:")
print(target_df['industry'].value_counts())
print(f"\nMerchants using product links: {target_df['uses_product_links'].sum()}")
print(f"Merchants not using product links: {len(target_df) - target_df['uses_product_links'].sum()}")
print("\nDistribution of active days in the last 60 days:")
print(target_df['date'].describe())
print("\nDistribution of average daily volume:")
print(target_df['average_total_volume_daily'].describe())
# Out:
#     merchantId country           industry  average_total_volume_daily  \
# 13    007f783b      US        Merchandise                      217.00
# 34    00ef7320      US  Business services                       38.84
# 40    012258f6      US  Business services                       27.97
# 84    022a82ae      US  Business services                       10.24
# 118   03027f34      US           Software                       11.48
#
#      uses_product_links  date
# 13                False    15
# 34                False    10
# 40                False    10
# 84                False     5
# 118               False     1
#
# Total number of target merchants: 165
#
# Merchants by country:
# country
# US    122
# GB     25
# AU     12
# HK      6
# Name: count, dtype: int64
#
# Merchants by industry:
# industry
# Business services    51
# Software             41
# Merchandise          35
# Education            24
# Personal services    14
# Name: count, dtype: int64
#
# ...

# %% [markdown]
# Finally, we will export these merchant IDs:

# %%
# After all the previous code...

# extract merchant IDs
merchant_ids = target_df['merchantId']

# export to CSV
merchant_ids.to_csv('target_merchant_ids_1.csv', index=False, header=['merchantId'])

print("\nTarget merchant IDs have been exported to 'target_merchant_ids.csv'")
# Out:
# Target merchant IDs have been exported to 'target_merchant_ids.csv'

# %%
merged_df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1577737 entries, 0 to 1577736
# Data columns (total 10 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   date                 1577737 non-null  datetime64[ns, UTC]
#  1   merchant             1577737 non-null  object
#  2   subscription_volume  1577737 non-null  float64
#  3   checkout_volume      1577737 non-null  float64
#  4   payment_link_volume  1577737 non-null  float64
#  5   total_volume         1577737 non-null  float64
#  6   industry             1577737 non-null  object
#  7   first_charge_date    1576638 non-null  datetime64[ns, UTC]
#  8   country              1577737 non-null  object
#  9   business_size        1577737 non-null  object
# dtypes: datetime64[ns, UTC](2), float64(4), object(4)
# memory usage: 120.4+ MB

# %% [markdown]
# ## Revised Analysis - Propensity Model

# %%
df = merged_df_filtered

# Step 1a: Create binary 'subscription_adopter' column
df['subscription_adopter'] = (df['subscription_volume'] > 0).astype(int)

# Get the reference date (last date in the dataset)
reference_date = df['date'].max()

# Step 1b: Aggregate data by merchant
merchant_data = df.groupby('merchant').agg({
    'total_volume': 'sum',
    'subscription_volume': 'sum',
    'checkout_volume': 'sum',
    'payment_link_volume': 'sum',
    'industry': 'last',
    'country': 'last',
    'business_size': 'last',
    'first_charge_date': 'first',
    'subscription_adopter': 'max'  # If any transaction had subscription, merchant is an adopter
})

# Calculate percentage of subscription volume
merchant_data['subscription_percentage'] = merchant_data['subscription_volume'] / merchant_data['total_volume']

# Convert first_charge_date to days since first charge
merchant_data['days_since_first_charge'] = (reference_date - merchant_data['first_charge_date']).dt.days

# Step 1c: Handle categorical variables
# Get top 10 countries and industries by total volume
top_10_countries = merchant_data.groupby('country')['total_volume'].sum().nlargest(10).index
top_10_industries = merchant_data.groupby('industry')['total_volume'].sum().nlargest(10).index

# Create dummy variables for top 10 countries and industries, and all business sizes
merchant_data['country'] = np.where(merchant_data['country'].isin(top_10_countries), merchant_data['country'], 'Other')
merchant_data['industry'] = np.where(merchant_data['industry'].isin(top_10_industries), merchant_data['industry'], 'Other')

merchant_data_encoded = pd.get_dummies(merchant_data, columns=['country', 'industry', 'business_size'], prefix=['country', 'industry', 'size'])

# Reset index to make 'merchant' a regular column
merchant_data_encoded = merchant_data_encoded.reset_index()

# Display the first few rows and data info
print(merchant_data_encoded.head())
print(merchant_data_encoded.info())

# Optional: Print the list of columns to verify the dummy variables
print(merchant_data_encoded.columns)
# Out:
#    merchant  total_volume  subscription_volume  checkout_volume  \
# 0  00085cb5      51600.00                 0.00         51600.00
# 1  000a45ba       1425.00               925.00             0.00
# 2  000e2c0e       9870.07              5201.24             0.00
# 3  001111d7      18659.95                 0.00             0.00
# 4  0015c036        162.00               162.00           138.00
#
#    payment_link_volume         first_charge_date  subscription_adopter  \
# 0                 0.00 2041-01-28 00:00:00+00:00                     0
# 1                 0.00 2040-06-01 00:00:00+00:00                     1
# 2                 0.00 2039-09-21 00:00:00+00:00                     1
# 3                 0.00 2042-04-24 00:00:00+00:00                     0
# 4                 0.00 2041-02-27 00:00:00+00:00                     1
#
#    subscription_percentage  days_since_first_charge  country_AU  ...  \
# 0                     0.00                   510.00       False  ...
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is called merchant_data_encoded

def plot_categorical_features(df, features, ncols=3):
    nrows = (len(features) - 1) // ncols + 1
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(5*ncols, 4*nrows))
    axes = axes.flatten()
    
    for ax, feature in zip(axes, features):
        sns.barplot(x=feature, y='subscription_adopter', data=df, ax=ax)
        ax.set_title(f'Adoption Rate by {feature}')
        ax.set_ylabel('Adoption Rate')
        ax.set_xlabel(feature)
        # Rotate labels and set alignment
        plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
        # Adjust subplot to make room for labels
        plt.setp(ax.get_xticklabels(), fontsize=8)
        ax.tick_params(axis='x', which='major', pad=0)
        fig.tight_layout()
    
    for ax in axes[len(features):]:
        ax.remove()
    
    plt.show()

def plot_numerical_features(df, features, ncols=3):
    nrows = (len(features) - 1) // ncols + 1
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(5*ncols, 4*nrows))
    axes = axes.flatten()
    
    for ax, feature in zip(axes, features):
        # Log transform the feature
        log_feature = np.log1p(df[feature])
        sns.histplot(data=df, x=log_feature, hue='subscription_adopter', element='step', stat='density', common_norm=False, ax=ax)
        ax.set_title(f'Log({feature}) by Adoption')
        ax.set_xlabel(f'Log({feature})')
        ax.set_ylabel('Density')
    
    for ax in axes[len(features):]:
        ax.remove()
    
    plt.tight_layout()
    plt.show()

# Identify categorical and numerical features
categorical_features = [col for col in merchant_data_encoded.columns if merchant_data_encoded[col].dtype == 'bool']
numerical_features = ['total_volume', 'checkout_volume', 'payment_link_volume', 'days_since_first_charge']

# Plot categorical features
plot_categorical_features(merchant_data_encoded, categorical_features)

# Plot numerical features
plot_numerical_features(merchant_data_encoded, numerical_features)

# Correlation heatmap
correlation_matrix = merchant_data_encoded.drop(['merchant', 'first_charge_date', 'subscription_adopter'], axis=1).corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Features')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, accuracy_score, classification_report
import statsmodels.api as sm

# Assuming your DataFrame is called merchant_data_encoded

# Feature engineering
volume_threshold = merchant_data_encoded['total_volume'].quantile(0.75)
merchant_data_encoded['is_high_volume'] = (merchant_data_encoded['total_volume'] > volume_threshold).astype(int)

merchant_data_encoded['customer_tenure_category'] = pd.cut(
    merchant_data_encoded['days_since_first_charge'],
    bins=[0, 180, 730, float('inf')],
    labels=['new', 'established', 'long-term']
)

tenure_dummies = pd.get_dummies(merchant_data_encoded['customer_tenure_category'], prefix='tenure', drop_first=True)
merchant_data_encoded = pd.concat([merchant_data_encoded, tenure_dummies], axis=1)

selected_features = [
    'country_JP', 'country_US', 'country_AU', 'country_DE', 'country_FR', 
    'country_GB', 'country_HK', 'country_IE', 'country_SG',bbb
    'industry_Business services',
    'industry_Medical services, drugs, testing labs & equipment medium',
    'industry_Software', 'industry_Clothing & accessory',
    'industry_Furnishing', 'industry_Merchandise',
    'industry_Specialty retail', 'industry_Ticketing & events',
    'is_high_volume', 'tenure_established', 'tenure_long-term'
]

X = merchant_data_encoded[selected_features]
y = merchant_data_encoded['subscription_adopter']

imputer = SimpleImputer(strategy='median')
X = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)

X = X.loc[:, ~X.columns.duplicated()]

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Use statsmodels to calculate p-values
X_train_scaled_with_const = sm.add_constant(X_train_scaled)  # Add an intercept to the model
logit_model = sm.Logit(y_train, X_train_scaled_with_const)  # Create logistic regression model with statsmodels
result = logit_model.fit()

# Extract p-values
p_values = result.pvalues[1:]  # Exclude the intercept

# Remove features with p-values > 0.05
significant_features = X.columns[p_values < 0.05].tolist()

# Filter X_train and X_test for significant features only
X_train_significant = X_train_scaled[:, p_values < 0.05]
X_test_significant = X_test_scaled[:, p_values < 0.05]

# Initialize and fit the logistic regression model with class weighting to handle imbalance
model = LogisticRegression(max_iter=1000, class_weight='balanced')
model.fit(X_train_significant, y_train)

# Predictions
y_pred = model.predict(X_test_significant)
y_pred_prob = model.predict_proba(X_test_significant)[:, 1]

# Evaluation
accuracy = accuracy_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_prob)
classification_report_output = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"ROC AUC Score: {roc_auc:.4f}")
print("Classification Report:")
print(classification_report_output)

# Feature Importance
feature_importance = pd.DataFrame({
    'feature': np.array(significant_features),
    'coefficient': model.coef_[0]
})
feature_importance['abs_importance'] = feature_importance['coefficient'].abs()
feature_importance = feature_importance.sort_values(by='abs_importance', ascending=False)

print("\nFeature Importance for Significant Features:")
print(feature_importance)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.439086
#          Iterations 7
# Accuracy: 0.6677
# ROC AUC Score: 0.7114
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.77      1915
#            1       0.31      0.64      0.42       447
#
#     accuracy                           0.67      2362
#    macro avg       0.60      0.66      0.59      2362
# weighted avg       0.78      0.67      0.70      2362
#
#
# Feature Importance for Significant Features:
#                                               feature  coefficient  \
# 5                                   industry_Software         0.39
# 13                                   tenure_long-term         0.27
# 7                                 industry_Furnishing        -0.24
# 3                          industry_Business services         0.22
# 6                       industry_Clothing & accessory        -0.22
# ...

# %%
# Remove duplicate columns if any
merchant_data_encoded = merchant_data_encoded.loc[:, ~merchant_data_encoded.columns.duplicated()]

# Filter the merchants based on your criteria
target_merchants = merchant_data_encoded[
    (merchant_data_encoded['subscription_adopter'] == 0) &  # Not adopted
    ((merchant_data_encoded['industry_Software'] == True) | 
     (merchant_data_encoded['industry_Business services'] == True)) &  # Industry filter
    ((merchant_data_encoded['country_US'] == True) | 
     (merchant_data_encoded['country_JP'] == True)) &  # Country filter
    (merchant_data_encoded['tenure_long-term'] == True)  # Long-term tenure
]
# Create a copy of the target_merchants DataFrame to avoid the SettingWithCopyWarning
target_merchants_copy = target_merchants.copy()

# Calculate the average daily volume safely
target_merchants_copy['average_daily_volume'] = target_merchants_copy['total_volume'] / target_merchants_copy['days_since_first_charge'].replace(0, np.nan)

# Now compute the summary again based on the copy
num_merchants = target_merchants_copy.shape[0]
percent_software = (target_merchants_copy['industry_Software'].mean()) * 100
percent_business_services = (target_merchants_copy['industry_Business services'].mean()) * 100
percent_us = (target_merchants_copy['country_US'].mean()) * 100
percent_jp = (target_merchants_copy['country_JP'].mean()) * 100
total_volume = target_merchants_copy['total_volume'].sum()
avg_daily_volume = target_merchants_copy['average_daily_volume'].mean()
avg_days_since_first_charge = target_merchants_copy['days_since_first_charge'].mean()

# Display the summary
summary = pd.DataFrame({
    'Number of Merchants': [num_merchants],
    '% in Software': [percent_software],
    '% in Business Services': [percent_business_services],
    '% in US': [percent_us],
    '% in JP': [percent_jp],
    'Total Volume': [total_volume],
    'Average Daily Volume': [avg_daily_volume],
    'Average Days Since First Charge': [avg_days_since_first_charge]
})

print(summary)
# Out:
#    Number of Merchants  % in Software  % in Business Services  % in US  \
# 0                  617          37.44                   62.56    94.17
#
#    % in JP  Total Volume  Average Daily Volume  \
# 0     5.83  177612641.63                196.95
#
#    Average Days Since First Charge
# 0                          1608.80

# %% [markdown]
# ## ROI Analysis #2

# %%
# 1. Calculate the current total and subscription volume for adopters
adopters = merchant_data_encoded[
    (merchant_data_encoded['subscription_adopter'] == 1) &  # Subscription adopters
    ((merchant_data_encoded['industry_Software'] == True) | 
     (merchant_data_encoded['industry_Business services'] == True)) &  # Industry filter
    ((merchant_data_encoded['country_US'] == True) | 
     (merchant_data_encoded['country_JP'] == True)) &  # Country filter
    (merchant_data_encoded['tenure_long-term'] == True)  # Long-term tenure
].copy()  # Make a copy to avoid slice warning

# Calculate total and subscription volume for adopters
total_adopter_volume = adopters['total_volume'].sum()
total_adopter_subscription_volume = adopters['subscription_volume'].sum()
num_adopters = adopters.shape[0]  # Get the number of current adopters

# Calculate average subscription volume per adopter
avg_subscription_volume_per_adopter = total_adopter_subscription_volume / num_adopters

# Print information about the adopters
print(f"Total volume for adopters: ${total_adopter_volume:,.2f}")
print(f"Total subscription volume for adopters: ${total_adopter_subscription_volume:,.2f}")
print(f"Average subscription revenue as % of total volume for adopters: {total_adopter_subscription_volume / total_adopter_volume * 100:.2f}%")
print(f"Number of current adopters: {num_adopters}\n")

# 2. What does it mean if adopters have 70% of their revenue from subscriptions?
# We assume that new adopters could potentially achieve similar subscription percentages.

# 70% of revenue from subscriptions is the benchmark for adopters
projected_subscription_percentage = 0.70

# 3. Conversion rate scenarios
conversion_rates = [0.01, 0.05, 0.10]  # 1%, 5%, 10%

# Step 4: Applying cannibalization factor (30% of revenue is cannibalized)
cannibalization_factor = 0.70  # 70% of the revenue is net new

# 5. Assume 3% of net new revenue is the revenue impact for the company
revenue_percentage = 0.03

# Calculate potential impact under each scenario
for rate in conversion_rates:
    expected_adopters = num_merchants * rate
    
    # Projected subscription volume based on average subscription volume per adopter
    potential_subscription_volume = expected_adopters * avg_subscription_volume_per_adopter * cannibalization_factor
    
    revenue_impact = potential_subscription_volume * revenue_percentage
    
    print(f"Conversion rate {rate*100}%:")
    print(f"  Expected adopters: {expected_adopters:.0f}")
    print(f"  Potential subscription volume: ${potential_subscription_volume:,.2f}")
    print(f"  Estimated revenue impact: ${revenue_impact:,.2f}\n")
# Out:
# Total volume for adopters: $487,728,284.34
# Total subscription volume for adopters: $262,444,276.70
# Average subscription revenue as % of total volume for adopters: 53.81%
# Number of current adopters: 542
#
# Conversion rate 1.0%:
#   Expected adopters: 6
#   Potential subscription volume: $2,091,322.57
#   Estimated revenue impact: $62,739.68
#
# Conversion rate 5.0%:
#   Expected adopters: 31
#   Potential subscription volume: $10,456,612.83
#   Estimated revenue impact: $313,698.38
#
# Conversion rate 10.0%:
#   Expected adopters: 62
#   Potential subscription volume: $20,913,225.67
#   Estimated revenue impact: $627,396.77

# %%
# 1. Calculate average daily subscription volume for adopters
adopters['average_daily_subscription_volume'] = adopters['subscription_volume'] / adopters['days_since_first_charge']

# Calculate average daily subscription volume across all adopters
avg_daily_subscription_volume = adopters['average_daily_subscription_volume'].mean()

# Project annual subscription volume by multiplying daily average by 365
projected_annual_subscription_volume_per_adopter = avg_daily_subscription_volume * 365

print(f"Average daily subscription volume for adopters: ${avg_daily_subscription_volume:.2f}")
print(f"Projected annual subscription volume per adopter: ${projected_annual_subscription_volume_per_adopter:,.2f}\n")

# 2. Conversion rate scenarios
conversion_rates = [0.01, 0.05, 0.10]  # 1%, 5%, 10%

# Step 3: Applying cannibalization factor (30% of revenue is cannibalized)
cannibalization_factor = 0.70  # 70% of the revenue is net new

# 4. Assume 3% of net new revenue is the revenue impact for the company
revenue_percentage = 0.03

# Calculate potential impact under each scenario
for rate in conversion_rates:
    expected_adopters = num_merchants * rate
    
    # Projected subscription volume for new adopters over a year
    potential_subscription_volume = expected_adopters * projected_annual_subscription_volume_per_adopter * cannibalization_factor
    
    # Calculate revenue impact
    revenue_impact = potential_subscription_volume * revenue_percentage
    
    print(f"Conversion rate {rate*100}%:")
    print(f"  Expected adopters: {expected_adopters:.0f}")
    print(f"  Projected annual subscription volume: ${potential_subscription_volume:,.2f}")
    print(f"  Estimated revenue impact: ${revenue_impact:,.2f}\n")
# Out:
# Average daily subscription volume for adopters: $237.49
# Projected annual subscription volume per adopter: $86,682.86
#
# Conversion rate 1.0%:
#   Expected adopters: 6
#   Projected annual subscription volume: $374,383.27
#   Estimated revenue impact: $11,231.50
#
# Conversion rate 5.0%:
#   Expected adopters: 31
#   Projected annual subscription volume: $1,871,916.34
#   Estimated revenue impact: $56,157.49
#
# Conversion rate 10.0%:
#   Expected adopters: 62
#   Projected annual subscription volume: $3,743,832.68
#   Estimated revenue impact: $112,314.98

# %%
# Export the list of merchant IDs to a CSV file
merchant_ids = target_merchants_copy[['merchant']]  # Assuming 'merchant' is the merchant ID column
merchant_ids.to_csv('merchant_ids_2.csv', index=False)

print("Merchant IDs exported to 'merchant_ids.csv'")
# Out:
# Merchant IDs exported to 'merchant_ids.csv'
